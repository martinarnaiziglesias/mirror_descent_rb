# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Lib.module.risk_budgeting import *
import student_mixture as sm
from tqdm import tqdm
from Lib.module.movidas import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
freq = 'B'
df_all = pd.concat([pd.read_excel('Data/SP_RC.xlsx',index_col=0, header=[0,1]), pd.read_excel('Data/SP_RC2.xlsx',index_col=0, header=[0,1])])
df_all = df_all.dropna(how='all').dropna(axis=1)
df_all = df_all.pct_change().dropna()
df_all = df_all.replace([np.inf, -np.inf], np.nan)
df_all = df_all[~df_all.index.duplicated(keep='first')]
first_level_index = df_all.columns.get_level_values(0)

# %%
import optuna

# %%
gamma_vol_smd = {10:None, 25:None, 50:None, 100:None, 250:None}

# %%
from scipy.optimize import minimize
def rb_vol(covariance_matrix, budgets):
    def objective_(x):
        return (np.dot(x,np.dot(covariance_matrix, x)) - np.dot(budgets, np.log(x)))
    x0 = np.ones(len(budgets))
    bnds = [(1e-8,None) for _ in range(len(budgets))]
    res = minimize(objective_, x0, bounds=bnds)
    return res.x, res.fun

for d in tqdm([10, 25, 50, 100, 250]):
    def objective(trial):
        gamma = trial.suggest_float('gamma', 0.001, 100)

        d = 10
        selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
        assets = first_level_index[selected_indices]
        nb_asset = len(assets)
        df = df_all[assets]
        X = df.values

        ### Fit Student-t mixture (2 components) to chosen stock returns
        n_sm = 1
        SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [4]).fit(X)
        SM_model.locations_ = np.array([np.zeros(nb_asset)])

        # ERC
        budgets = np.ones(nb_asset)/nb_asset 

        y_ref, _ = rb_vol(SM_model.scales_[0], budgets)
        SM_theta = y_ref/y_ref.sum()

        n_val=250000
        X = SM_model.rvs(n_val)
        np.random.shuffle(X)

        y_sgd = budgets / np.std(X, axis=0)
        xi_sgd = 0
        c_sgd = .55

        y_smd = budgets / np.std(X, axis=0)
        xi_smd = 0
        c_smd = .55
        M = 65

        # y_sgd_s = [y_sgd]
        # xi_sgd_s = [xi_sgd]

        # y_smd_s = [y_smd]
        # xi_smd_s = [xi_smd]
        y_sgd_s = 0
        y_smd_s = 0

        for k in range(1, n_val):
            x = X[k]
            
            ### SGD
            # gradient
            step_size_sgd = gamma/k**c_sgd
            grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
            grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)

            #descent
            y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
            y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
            xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
            # y_bar_sgd_numerator += y_sgd*step_size_sgd
            # y_bar_sgd_denominator += step_size_sgd

            ### SMD
            # gradient
            step_size_smd = gamma/k**c_smd
            grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
            grad_xi_smd = -2 * (np.dot(y_smd,x) - xi_smd)

            y_smd_min = min(min(y_smd),1)
            y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
            xi_smd = xi_smd - step_size_smd*grad_xi_smd
            sum_y_smd = np.sum(y_smd)
            if sum_y_smd>M:
                y_smd = M/sum_y_smd*y_smd

            if k>200000:
                y_sgd_s+=y_sgd
                y_smd_s+=y_smd
        
        theta_sgd = y_sgd_s/(n_val-200000)
        theta_smd = y_smd_s/(n_val-200000)

        return np.linalg.norm(SM_theta-theta_smd/theta_smd.sum())


    study = optuna.create_study()
    study.optimize(objective, n_trials=100)

    gamma_vol_smd[d] = study.best_params['gamma']  # E.g. {'x': 2.002108042}
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s][I 2024-11-05 13:16:12,858] A new study created in memory with name: no-name-3bb87db4-03d5-4b95-9511-e9c1f48b47db
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:16:23,940] Trial 0 failed with parameters: {'gamma': 49.8881381177025} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:16:23,941] Trial 0 failed with value nan.
# [I 2024-11-05 13:16:33,916] Trial 1 finished with value: 0.001100862438166945 and parameters: {'gamma': 0.7245665986751271}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:16:45,616] Trial 2 failed with parameters: {'gamma': 88.15073503194529} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:16:45,617] Trial 2 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:63: RuntimeWarning: invalid value encountered in subtract
#   y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:16:59,128] Trial 3 failed with parameters: {'gamma': 99.41229446258735} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:16:59,129] Trial 3 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:17:11,860] Trial 4 failed with parameters: {'gamma': 56.770513236596784} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:17:11,861] Trial 4 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:17:26,755] Trial 5 failed with parameters: {'gamma': 98.94161906955692} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:17:26,755] Trial 5 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:17:37,506] Trial 6 failed with parameters: {'gamma': 61.056405041233646} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:17:37,507] Trial 6 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:17:47,062] Trial 7 failed with parameters: {'gamma': 50.32109535728191} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:17:47,062] Trial 7 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:17:58,242] Trial 8 failed with parameters: {'gamma': 90.2618308893025} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:17:58,243] Trial 8 failed with value nan.
# [I 2024-11-05 13:18:09,747] Trial 9 finished with value: 0.0043339465462167055 and parameters: {'gamma': 33.10660558820254}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:18:19,732] Trial 10 failed with parameters: {'gamma': 13.15847599391004} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:18:19,733] Trial 10 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:18:31,168] Trial 11 failed with parameters: {'gamma': 12.831132529786933} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:18:31,169] Trial 11 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:18:39,486] Trial 12 failed with parameters: {'gamma': 48.815250020434036} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:18:39,487] Trial 12 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# [W 2024-11-05 13:18:47,161] Trial 13 failed with parameters: {'gamma': 13.492039251681568} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:18:47,162] Trial 13 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:63: RuntimeWarning: invalid value encountered in subtract
#   y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:18:54,737] Trial 14 failed with parameters: {'gamma': 55.75124904767827} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:18:54,738] Trial 14 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# [W 2024-11-05 13:19:02,290] Trial 15 failed with parameters: {'gamma': 39.372642287427574} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:19:02,291] Trial 15 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:19:17,221] Trial 16 failed with parameters: {'gamma': 36.67573074092065} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:19:17,222] Trial 16 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:19:49,879] Trial 17 failed with parameters: {'gamma': 90.73562800096515} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:19:49,882] Trial 17 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:20:20,171] Trial 18 failed with parameters: {'gamma': 37.40601578623171} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:20:20,173] Trial 18 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:20:47,873] Trial 19 failed with parameters: {'gamma': 11.06013762054411} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:20:47,874] Trial 19 failed with value nan.
# [I 2024-11-05 13:20:57,121] Trial 20 finished with value: 0.002570182023042359 and parameters: {'gamma': 25.523122498556166}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: invalid value encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:21:16,580] Trial 21 failed with parameters: {'gamma': 75.76032583002574} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:21:16,582] Trial 21 failed with value nan.
# [I 2024-11-05 13:21:49,164] Trial 22 finished with value: 0.00246051492959664 and parameters: {'gamma': 6.046122734733163}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:22:19,290] Trial 23 failed with parameters: {'gamma': 45.99129435423216} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:22:19,292] Trial 23 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: overflow encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:22:52,354] Trial 24 failed with parameters: {'gamma': 82.40759003545153} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:22:52,355] Trial 24 failed with value nan.
# [I 2024-11-05 13:23:19,666] Trial 25 finished with value: 0.002400985095578233 and parameters: {'gamma': 11.986579250396751}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:23:48,124] Trial 26 failed with parameters: {'gamma': 49.804510937220456} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:23:48,126] Trial 26 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:24:16,683] Trial 27 failed with parameters: {'gamma': 56.89231281294566} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:24:16,684] Trial 27 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:24:44,262] Trial 28 failed with parameters: {'gamma': 22.67196177786411} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:24:44,263] Trial 28 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:83: RuntimeWarning: overflow encountered in add
#   y_sgd_s+=y_sgd
# [W 2024-11-05 13:25:08,940] Trial 29 failed with parameters: {'gamma': 40.72742415873664} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:25:08,941] Trial 29 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:25:33,582] Trial 30 failed with parameters: {'gamma': 23.680131640136832} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:25:33,583] Trial 30 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: invalid value encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:26:01,745] Trial 31 failed with parameters: {'gamma': 60.82584765577464} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:26:01,746] Trial 31 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: overflow encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:26:30,825] Trial 32 failed with parameters: {'gamma': 69.67335676458902} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:26:30,826] Trial 32 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:27:00,097] Trial 33 failed with parameters: {'gamma': 92.69700684996215} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:27:00,098] Trial 33 failed with value nan.
# [I 2024-11-05 13:27:30,652] Trial 34 finished with value: 0.0018260993694330459 and parameters: {'gamma': 13.891079088854237}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: overflow encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:27:59,498] Trial 35 failed with parameters: {'gamma': 62.48336581502295} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:27:59,499] Trial 35 failed with value nan.
# [I 2024-11-05 13:28:26,893] Trial 36 finished with value: 0.0022274121537070794 and parameters: {'gamma': 11.901658479042435}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:28:55,701] Trial 37 failed with parameters: {'gamma': 91.83224313240704} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:28:55,702] Trial 37 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: invalid value encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:29:21,404] Trial 38 failed with parameters: {'gamma': 46.064552197232956} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:29:21,405] Trial 38 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:29:46,145] Trial 39 failed with parameters: {'gamma': 67.0093346384359} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:29:46,146] Trial 39 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:30:12,905] Trial 40 failed with parameters: {'gamma': 63.03610922458149} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:30:12,906] Trial 40 failed with value nan.
# [I 2024-11-05 13:30:42,012] Trial 41 finished with value: 0.002813288625675296 and parameters: {'gamma': 2.6030587670629397}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:31:11,420] Trial 42 failed with parameters: {'gamma': 82.40996354290277} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:31:11,421] Trial 42 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:31:40,457] Trial 43 failed with parameters: {'gamma': 64.71533253486916} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:31:40,458] Trial 43 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# [W 2024-11-05 13:32:13,970] Trial 44 failed with parameters: {'gamma': 33.046885108976625} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:32:13,971] Trial 44 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# [W 2024-11-05 13:32:39,538] Trial 45 failed with parameters: {'gamma': 24.45930528984905} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:32:39,539] Trial 45 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:33:06,282] Trial 46 failed with parameters: {'gamma': 41.493168404625955} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:33:06,284] Trial 46 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:33:31,971] Trial 47 failed with parameters: {'gamma': 75.70350538902501} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:33:31,972] Trial 47 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:33:58,903] Trial 48 failed with parameters: {'gamma': 98.92385585220646} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:33:58,904] Trial 48 failed with value nan.
# [I 2024-11-05 13:34:25,278] Trial 49 finished with value: 0.002069296920228726 and parameters: {'gamma': 29.18152899836002}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:34:54,479] Trial 50 failed with parameters: {'gamma': 89.36940395455997} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:34:54,480] Trial 50 failed with value nan.
# [I 2024-11-05 13:35:20,224] Trial 51 finished with value: 0.004706539482095595 and parameters: {'gamma': 3.6490400884798024}. Best is trial 1 with value: 0.001100862438166945.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:35:48,164] Trial 52 failed with parameters: {'gamma': 74.359797656054} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:35:48,165] Trial 52 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 13:36:16,158] Trial 53 failed with parameters: {'gamma': 77.08335089103446} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:36:16,159] Trial 53 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: invalid value encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: invalid value encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 13:36:47,590] Trial 54 failed with parameters: {'gamma': 78.45636628079335} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 13:36:47,592] Trial 54 failed with value nan.
# ...
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:28:59,576] Trial 84 failed with parameters: {'gamma': 76.26079636845651} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:28:59,577] Trial 84 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:29:25,184] Trial 85 failed with parameters: {'gamma': 75.29539134250894} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:29:25,186] Trial 85 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: overflow encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:29:53,611] Trial 86 failed with parameters: {'gamma': 67.66087175618287} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:29:53,612] Trial 86 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 15:30:21,592] Trial 87 failed with parameters: {'gamma': 80.87166931178399} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:30:21,594] Trial 87 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:30:51,718] Trial 88 failed with parameters: {'gamma': 72.886696688879} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:30:51,719] Trial 88 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:31:16,092] Trial 89 failed with parameters: {'gamma': 78.9666575133686} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:31:16,094] Trial 89 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:31:40,517] Trial 90 failed with parameters: {'gamma': 74.87429309366769} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:31:40,518] Trial 90 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:32:07,151] Trial 91 failed with parameters: {'gamma': 78.46638105835753} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:32:07,152] Trial 91 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 15:32:37,184] Trial 92 failed with parameters: {'gamma': 78.05541720457714} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:32:37,185] Trial 92 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 15:33:04,041] Trial 93 failed with parameters: {'gamma': 75.22376493932475} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:33:04,042] Trial 93 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:33:32,354] Trial 94 failed with parameters: {'gamma': 76.99652900409126} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:33:32,355] Trial 94 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 15:33:59,852] Trial 95 failed with parameters: {'gamma': 77.1385763836829} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:33:59,853] Trial 95 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:34:27,305] Trial 96 failed with parameters: {'gamma': 78.12610373266706} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:34:27,307] Trial 96 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:59: RuntimeWarning: overflow encountered in double_scalars
#   grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:60: RuntimeWarning: overflow encountered in double_scalars
#   grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)
# [W 2024-11-05 15:34:57,907] Trial 97 failed with parameters: {'gamma': 77.62528650586985} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:34:57,908] Trial 97 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: overflow encountered in exp
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:80: RuntimeWarning: invalid value encountered in multiply
#   y_smd = M/sum_y_smd*y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:35:27,907] Trial 98 failed with parameters: {'gamma': 74.11614234663432} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:35:27,908] Trial 98 failed with value nan.
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:72: RuntimeWarning: divide by zero encountered in divide
#   grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:76: RuntimeWarning: invalid value encountered in multiply
#   y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: overflow encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_19508\3758543246.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
# [W 2024-11-05 15:35:53,136] Trial 99 failed with parameters: {'gamma': 76.16361960290473} because of the following error: The value nan is not acceptable.
# [W 2024-11-05 15:35:53,137] Trial 99 failed with value nan.
# 100%|██████████| 5/5 [2:19:40<00:00, 1676.06s/it]

# %%
gamma_vol_smd
# Out:
# {10: 0.7245665986751271,
#  25: 11.887381340662849,
#  50: 1.05686892495071,
#  100: 0.349049378703292,
#  250: 14.261145119212394}

# %%
study.best_params['gamma']
# Out:
# 14.261145119212394

# %%
y_sgd_s

# %%
d = 25
selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

### Fit Student-t mixture (2 components) to chosen stock returns
n_sm = 2
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [2.5,4]).fit(X)

# ERC
budgets = np.ones(nb_asset)/nb_asset 
# Expected Shortfall alpha
alpha = .95 

SM_theta, optim_res = StudentMixtureExpectedShortfall(SM_model).solve_risk_budgeting(budgets, alpha, on_simplex=False, kappa=1, method=None, maxiter=15000)
VaR_port = StudentMixtureExpectedShortfall(SM_model).value_at_risk(SM_theta, alpha)
ES_port = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(SM_theta, alpha)
risk_contribs = SM_theta * StudentMixtureExpectedShortfall(SM_model).expected_shortfall_gradient(SM_theta, alpha)

optimal_loss = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(optim_res.x, alpha) - np.dot(budgets, np.log(optim_res.x))

n_val=1000000
X = SM_model.rvs(n_val)
np.random.shuffle(X)

gamma = 2.5

y_sgd = budgets / np.std(X, axis=0)
xi_sgd = 0
c_sgd = .65

y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .65
M = 500

y_sgd_s = [y_sgd]
xi_sgd_s = [xi_sgd]


y_smd_s = [y_smd]
xi_smd_s = [xi_smd]

freq_y = 10000

for k in tqdm(range(1, n_val)):
    x = X[k]
    
    ### SGD
    # gradient
    step_size_sgd = gamma/k**c_sgd
    indicator_sgd = -np.dot(y_sgd, x) - xi_sgd >= 0
    grad_y_sgd = -x/(1-alpha)*indicator_sgd - budgets/y_sgd
    grad_xi_sgd = 1 - (1 / (1 - alpha)) * indicator_sgd

    #descent
    y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
    y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
    xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
    # y_bar_sgd_numerator += y_sgd*step_size_sgd
    # y_bar_sgd_denominator += step_size_sgd

    ### SMD
    # gradient
    step_size_smd = gamma/k**c_smd
    indicator_smd = -np.dot(y_smd, x) - xi_smd >= 0
    grad_y_smd = -x/(1-alpha)*indicator_smd - budgets/y_smd
    grad_xi_smd = 1 - (1 / (1 - alpha)) * indicator_smd

    y_smd_min = min(min(y_smd),1)
    y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
    xi_smd = xi_smd - step_size_smd*grad_xi_smd
    sum_y_smd = np.sum(y_smd)
    if sum_y_smd>M:
        y_smd = M/sum_y_smd*y_smd

    if k%freq_y==0:
        y_sgd_s.append(y_sgd)
        xi_sgd_s.append(xi_sgd)
        y_smd_s.append(y_smd)
        xi_smd_s.append(xi_smd)
# Out:
# 100%|██████████| 999999/999999 [00:52<00:00, 19181.27it/s]

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 8))
ax[0][0].plot(y_sgd_s, lw=1)
ax[0][0].set_title('SGD')
ax[0][1].plot(y_smd_s, lw=1)
ax[0][1].set_title('SMD')
ax[0][0].hlines(optim_res.x, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[0][1].hlines(optim_res.x, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[0].set_ylim(0, 100) 
# ax[1].set_ylim(0, 20) 

ax[1][0].plot(xi_sgd_s, lw=1)
ax[1][0].set_title('SGD')
ax[1][1].plot(xi_smd_s, lw=1)
ax[1][1].set_title('SMD')
ax[1][0].hlines(VaR_port*sum(optim_res.x), 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[1][1].hlines(VaR_port*sum(optim_res.x), 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[2].set_ylim(0, 100)
# ax[3].set_ylim(0, 20)
plt.tight_layout()
plt.show()

# %% [markdown]
# Volatility

# %%
from scipy.optimize import minimize

gamma_vol = {10: 2, 25:2.25, 50:2.25, 100:3.2, 250:3.35}

def rb_vol(covariance_matrix, budgets):
    def objective(x):
        return (np.dot(x,np.dot(covariance_matrix, x)) - np.dot(budgets, np.log(x)))
    x0 = np.ones(len(budgets))
    bnds = [(1e-8,None) for _ in range(len(budgets))]
    res = minimize(objective, x0, bounds=bnds)
    return res.x, res.fun


d = 250
selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

### Fit Student-t mixture (2 components) to chosen stock returns
n_sm = 1
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [4]).fit(X)
SM_model.locations_ = np.array([np.zeros(nb_asset)])

# ERC
budgets = np.ones(nb_asset)/nb_asset 

y_ref, _ = rb_vol(SM_model.scales_[0], budgets)
SM_theta = y_ref/y_ref.sum()

n_val=1000000
X = SM_model.rvs(n_val)
np.random.shuffle(X)

gamma = 4

y_sgd = budgets / np.std(X, axis=0)
xi_sgd = 0
c_sgd = .55

y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .55
M = 1000

y_sgd_s = [y_sgd]
xi_sgd_s = [xi_sgd]


y_smd_s = [y_smd]
xi_smd_s = [xi_smd]

freq_y = 10000

for k in tqdm(range(1, n_val)):
    x = X[k]
    
    ### SGD
    # gradient
    step_size_sgd = gamma/k**c_sgd
    grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
    grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)

    #descent
    y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
    y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
    xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
    # y_bar_sgd_numerator += y_sgd*step_size_sgd
    # y_bar_sgd_denominator += step_size_sgd

    ### SMD
    # gradient
    step_size_smd = gamma/k**c_smd
    grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
    grad_xi_smd = -2 * (np.dot(y_smd,x) - xi_smd)

    y_smd_min = min(min(y_smd),1)
    y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
    xi_smd = xi_smd - step_size_smd*grad_xi_smd
    sum_y_smd = np.sum(y_smd)
    if sum_y_smd>M:
        y_smd = M/sum_y_smd*y_smd

    if k%freq_y==0:
        y_sgd_s.append(y_sgd)
        xi_sgd_s.append(xi_sgd)
        y_smd_s.append(y_smd)
        xi_smd_s.append(xi_smd)
# Out:
# 100%|██████████| 999999/999999 [00:55<00:00, 17948.54it/s]

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 8))
ax[0][0].plot(np.array(y_sgd_s)/np.array(y_sgd_s).sum(axis=1)[:,None], lw=1)
ax[0][0].set_title('SGD')
ax[0][1].plot(np.array(y_smd_s)/np.array(y_smd_s).sum(axis=1)[:,None], lw=1)
ax[0][1].set_title('SMD')
ax[0][0].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[0][1].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[0].set_ylim(0, 100) 
# ax[1].set_ylim(0, 20) 

ax[1][0].plot(xi_sgd_s, lw=1)
ax[1][0].set_title('SGD')
ax[1][1].plot(xi_smd_s, lw=1)
ax[1][1].set_title('SMD')
ax[1][0].hlines(0, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[1][1].hlines(0, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[2].set_ylim(0, 100)
# ax[3].set_ylim(0, 20)
plt.tight_layout()
plt.show()

# %% [markdown]
# Variantile

# %%
from scipy.optimize import minimize

gamma_variantile = {10: 10, 25:12, 50:15, 100:18, 250:3.35}

def rb_vol(covariance_matrix, budgets):
    def objective(x):
        return (np.dot(x,np.dot(covariance_matrix, x)) - np.dot(budgets, np.log(x)))
    x0 = np.ones(len(budgets))
    bnds = [(1e-8,None) for _ in range(len(budgets))]
    res = minimize(objective, x0, bounds=bnds)
    return res.x, res.fun


d = 250
selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

### Fit Student-t mixture (2 components) to chosen stock returns
n_sm = 1
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [4]).fit(X)
SM_model.locations_ = np.array([np.zeros(nb_asset)])

# ERC
budgets = np.ones(nb_asset)/nb_asset 

y_ref, _ = rb_vol(SM_model.scales_[0], budgets)
SM_theta = y_ref/y_ref.sum()

n_val=1000000
X = SM_model.rvs(n_val)
np.random.shuffle(X)

alpha = .9

gamma = 20

y_sgd = budgets / np.std(X, axis=0)
xi_sgd = 0
c_sgd = .55

y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .55
M = 1000

y_sgd_s = [y_sgd]
xi_sgd_s = [xi_sgd]


y_smd_s = [y_smd]
xi_smd_s = [xi_smd]

freq_y = 10000

for k in tqdm(range(1, n_val)):
    x = X[k]
    
    ### SGD
    # gradient
    step_size_sgd = gamma/k**c_sgd
    loss_sgd = -np.dot(y_sgd, x)
    indicator_pos_sgd = loss_sgd - xi_sgd >= 0
    indicator_neg_sgd = loss_sgd - xi_sgd < 0
    grad_y_sgd = -2 * alpha * (loss_sgd - xi_sgd) * x * indicator_pos_sgd + -2 * (1 - alpha) * (loss_sgd - xi_sgd) * x * indicator_neg_sgd - budgets/y_sgd
    grad_xi_sgd = -2 * alpha * (loss_sgd - xi_sgd) * indicator_pos_sgd + -2 * (1 - alpha) * (loss_sgd - xi_sgd) * indicator_neg_sgd

    #descent
    y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
    y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
    xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
    # y_bar_sgd_numerator += y_sgd*step_size_sgd
    # y_bar_sgd_denominator += step_size_sgd

    ### SMD
    # gradient
    step_size_smd = gamma/k**c_smd
    loss_smd = -np.dot(y_smd, x)
    indicator_pos_smd = loss_smd - xi_smd >= 0
    indicator_neg_smd = loss_smd - xi_smd < 0
    grad_y_smd = -2 * alpha * (loss_smd - xi_smd) * x * indicator_pos_smd + -2 * (1 - alpha) * (loss_smd - xi_smd) * x * indicator_neg_smd - budgets/y_smd
    grad_xi_smd = -2 * alpha * (loss_smd - xi_smd) * indicator_pos_smd + -2 * (1 - alpha) * (loss_smd - xi_smd) * indicator_neg_smd

    y_smd_min = min(min(y_smd),1)
    y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
    xi_smd = xi_smd - step_size_smd*grad_xi_smd
    sum_y_smd = np.sum(y_smd)
    if sum_y_smd>M:
        y_smd = M/sum_y_smd*y_smd

    if k%freq_y==0:
        y_sgd_s.append(y_sgd)
        xi_sgd_s.append(xi_sgd)
        y_smd_s.append(y_smd)
        xi_smd_s.append(xi_smd)
# Out:
#  14%|█▎        | 136087/999999 [00:08<00:58, 14781.87it/s]

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 8))
ax[0][0].plot(np.array(y_sgd_s)/np.array(y_sgd_s).sum(axis=1)[:,None], lw=1)
ax[0][0].set_title('SGD')
ax[0][1].plot(np.array(y_smd_s)/np.array(y_smd_s).sum(axis=1)[:,None], lw=1)
ax[0][1].set_title('SMD')
ax[0][0].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[0][1].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[0].set_ylim(0, 100) 
# ax[1].set_ylim(0, 20) 

ax[1][0].plot(xi_sgd_s, lw=1)
ax[1][0].set_title('SGD')
ax[1][1].plot(xi_smd_s, lw=1)
ax[1][1].set_title('SMD')
ax[1][0].hlines(0, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[1][1].hlines(0, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[2].set_ylim(0, 100)
# ax[3].set_ylim(0, 20)
plt.tight_layout()
plt.show()

# %%
sum(y_smd)
# Out:
# 100.10296942124273

# %% [markdown]
# MAD

# %%
from scipy.optimize import minimize

def rb_vol(covariance_matrix, budgets):
    def objective(x):
        return (np.dot(x,np.dot(covariance_matrix, x)) - np.dot(budgets, np.log(x)))
    x0 = np.ones(len(budgets))
    bnds = [(1e-8,None) for _ in range(len(budgets))]
    res = minimize(objective, x0, bounds=bnds)
    return res.x, res.fun


d = 10
selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

### Fit Student-t mixture (1 components) to chosen stock returns
n_sm = 1
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [4]).fit(X)
SM_model.locations_ = np.array([np.zeros(nb_asset)])

# ERC
budgets = np.ones(nb_asset)/nb_asset 

y_ref, _ = rb_vol(SM_model.scales_[0], budgets)
SM_theta = y_ref/y_ref.sum()

n_val=1000000
X = SM_model.rvs(n_val)
np.random.shuffle(X)

gamma = 50

y_sgd = budgets / np.std(X, axis=0)
xi_sgd = 0
c_sgd = .65

y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .65
M = 200

y_sgd_s = [y_sgd]
xi_sgd_s = [xi_sgd]


y_smd_s = [y_smd]
xi_smd_s = [xi_smd]

freq_y = 10000

for k in tqdm(range(1, n_val)):
    x = X[k]
    
    ### SGD
    # gradient
    step_size_sgd = gamma/k**c_sgd
    loss_sgd = -np.dot(y_sgd, x)
    indicator_pos_sgd = (loss_sgd - xi_sgd >= 0)*1
    indicator_neg_sgd = 1 - indicator_pos_sgd
    grad_y_sgd = (indicator_neg_sgd - indicator_pos_sgd)*x - budgets/y_sgd
    grad_xi_sgd = indicator_neg_sgd - indicator_pos_sgd

    #descent
    y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
    y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
    xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
    # y_bar_sgd_numerator += y_sgd*step_size_sgd
    # y_bar_sgd_denominator += step_size_sgd

    ### SMD
    # gradient
    step_size_smd = gamma/k**c_smd
    loss_smd = -np.dot(y_smd, x)
    indicator_pos_smd = (loss_smd - xi_smd >= 0)*1
    indicator_neg_smd = 1-indicator_pos_smd
    grad_y_smd = (indicator_neg_smd - indicator_pos_smd)*x - budgets/y_smd 
    grad_xi_smd = indicator_neg_smd - indicator_pos_smd

    y_smd_min = min(min(y_smd),1)
    y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
    xi_smd = xi_smd - step_size_smd*grad_xi_smd
    sum_y_smd = np.sum(y_smd)
    if sum_y_smd>M:
        y_smd = M/sum_y_smd*y_smd

    if k%freq_y==0:
        y_sgd_s.append(y_sgd)
        xi_sgd_s.append(xi_sgd)
        y_smd_s.append(y_smd)
        xi_smd_s.append(xi_smd)
# Out:
# 100%|██████████| 1999999/1999999 [01:15<00:00, 26447.24it/s]

# %%
sum(y_smd)
# Out:
# 112.58514723983157

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 8))
ax[0][0].plot(np.array(y_sgd_s)/np.array(y_sgd_s).sum(axis=1)[:,None], lw=1)
ax[0][0].set_title('SGD')
ax[0][1].plot(np.array(y_smd_s)/np.array(y_smd_s).sum(axis=1)[:,None], lw=1)
ax[0][1].set_title('SMD')
ax[0][0].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[0][1].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[0].set_ylim(0, 100) 
# ax[1].set_ylim(0, 20) 

ax[1][0].plot(xi_sgd_s, lw=1)
ax[1][0].set_title('SGD')
ax[1][1].plot(xi_smd_s, lw=1)
ax[1][1].set_title('SMD')
ax[1][0].hlines(0, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[1][1].hlines(0, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[2].set_ylim(0, 100)
# ax[3].set_ylim(0, 20)
plt.tight_layout()
plt.show()

# %%
from scipy.optimize import minimize

def rb_vol(covariance_matrix, budgets):
    def objective(x):
        return (np.dot(x,np.dot(covariance_matrix, x)) - np.dot(budgets, np.log(x)))
    x0 = np.ones(len(budgets))
    bnds = [(1e-8,None) for _ in range(len(budgets))]
    res = minimize(objective, x0, bounds=bnds)
    return res.x, res.fun

# gamma_tamed = {10:1, 25:.5, 50:.3, 100:2, 250:25}
np.random.seed(0)

d = 10
selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

### Fit Student-t mixture (2 components) to chosen stock returns
n_sm = 2
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [2.5,4]).fit(X)

# ERC
budgets = np.ones(nb_asset)/nb_asset 

n_val=1000000
X = SM_model.rvs(n_val)
np.random.shuffle(X)

vcv = np.cov(X, rowvar=False)
optim_res, optimal_loss = rb_vol(vcv, budgets)
SM_theta = optim_res/optim_res.sum()

gamma = 2

y_sgd = budgets / np.std(X, axis=0)
xi_sgd = 0
c_sgd = .65

y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .65
M = 100

y_sgd_s = [y_sgd]
xi_sgd_s = [xi_sgd]


y_smd_s = [y_smd]
xi_smd_s = [xi_smd]

freq_y = 10000

for k in tqdm(range(1, n_val)):
    x = X[k]
    
    ### SGD
    # gradient
    step_size_sgd = gamma/k**c_sgd
    grad_y_sgd = 2 * (np.dot(y_sgd,x) - xi_sgd)*x - budgets/y_sgd
    grad_xi_sgd = -2 * (np.dot(y_sgd,x) - xi_sgd)

    #descent
    y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
    y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
    xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
    # y_bar_sgd_numerator += y_sgd*step_size_sgd
    # y_bar_sgd_denominator += step_size_sgd

    ### SMD
    # gradient
    step_size_smd = gamma/k**c_smd
    grad_y_smd = 2 * (np.dot(y_smd,x) - xi_smd)*x - budgets/y_smd
    grad_xi_smd = -2 * (np.dot(y_smd,x) - xi_smd)

    y_smd_min = min(min(y_smd),1)
    y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
    xi_smd = xi_smd - step_size_smd*grad_xi_smd
    sum_y_smd = np.sum(y_smd)
    if sum_y_smd>M:
        y_smd = M/sum_y_smd*y_smd

    if k%freq_y==0:
        y_sgd_s.append(y_sgd)
        xi_sgd_s.append(xi_sgd)
        y_smd_s.append(y_smd)
        xi_smd_s.append(xi_smd)
# Out:
# 100%|██████████| 999999/999999 [00:43<00:00, 22822.24it/s]

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 8))
ax[0][0].plot(y_sgd_s, lw=1)
ax[0][0].set_title('SGD')
ax[0][1].plot(y_smd_s, lw=1)
ax[0][1].set_title('SMD')
ax[0][0].hlines(optim_res, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[0][1].hlines(optim_res, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[0].set_ylim(0, 100) 
# ax[1].set_ylim(0, 20) 

# ax[1][0].plot(xi_sgd_s, lw=1)
# ax[1][0].set_title('SGD')
# ax[1][1].plot(xi_smd_s, lw=1)
# ax[1][1].set_title('SMD')
# ax[1][0].hlines(VaR_port*sum(optim_res), 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[1][1].hlines(VaR_port*sum(optim_res), 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[2].set_ylim(0, 100)
# ax[3].set_ylim(0, 20)
plt.tight_layout()
plt.show()

# %% [markdown]
# MAD

# %% [markdown]
# Variantile

# %%
# gamma_tamed = {10:.75, 25:.5, 50:.3, 100:2, 250:25}

d = 10
alpha = .9
gamma = 1
# ERC
budgets = np.ones(nb_asset)/nb_asset 

selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

### Fit Student-t mixture (2 components) to chosen stock returns
n_sm = 2
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [2.5,4]).fit(X)


### reference portfolio
y_ref = 0
polyak_ruppert = .2
n_ref = 1000000
X = SM_model.rvs(n_ref)
np.random.shuffle(X)
y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .65
M = 100
n_epoch = 2
j = 1
for _ in tqdm(range(n_epoch)):
    np.random.shuffle(X)   
    for k in range(1, n_ref):
        x = X[k]
        step_size_smd = gamma/j**c_smd
        loss_smd = -np.dot(y_smd, x)
        indicator_pos_smd = loss_smd - xi_smd >= 0
        indicator_neg_smd = loss_smd - xi_smd < 0
        grad_y_smd = -2 * alpha * (loss_smd - xi_smd) * x * indicator_pos_smd + -2 * (1 - alpha) * (loss_smd - xi_smd) * x * indicator_neg_smd - budgets/y_smd
        grad_xi_smd = -2 * alpha * (loss_smd - xi_smd) * indicator_pos_smd + -2 * (1 - alpha) * (loss_smd - xi_smd) * indicator_neg_smd

        y_smd_min = min(min(y_smd),1)
        y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
        xi_smd = xi_smd - step_size_smd*grad_xi_smd
        sum_y_smd = np.sum(y_smd)
        if sum_y_smd>M:
            y_smd = M/sum_y_smd*y_smd   
        if j>int((1-polyak_ruppert)*n_ref*n_epoch):
            y_ref += y_smd
            j += 1
y_ref = y_ref/(j-1)
SM_theta = y_ref/np.sum(y_ref)


n_val=1000000
X = SM_model.rvs(n_val)
np.random.shuffle(X)

y_sgd = budgets / np.std(X, axis=0)
xi_sgd = 0
c_sgd = .65

y_smd = budgets / np.std(X, axis=0)
xi_smd = 0
c_smd = .65
M = 100

y_sgd_s = [y_sgd]
xi_sgd_s = [xi_sgd]


y_smd_s = [y_smd]
xi_smd_s = [xi_smd]

freq_y = 10000

for k in tqdm(range(1, n_val)):
    x = X[k]
    
    ### SGD
    # gradient

                    # loss = -np.dot(y, x.T)
                    # indicator_pos = (loss - t >= 0).reshape((x.shape[0], 1))
                    # indicator_neg = (loss - t < 0).reshape((x.shape[0], 1))
                    # grad_t = np.mean(
                    #     self.beta * -2 * self.alpha * (loss - t) * indicator_pos + -2 * (1 - self.alpha) * (
                    #             loss - t) * indicator_neg)
                    # grad_y = np.mean(self.beta *
                    #                  -2 * self.alpha * (loss - t).reshape((x.shape[0], 1)) * x * indicator_pos + -2 * (
                    #                          1 - self.alpha) * (loss - t).reshape(
                    #     (x.shape[0], 1)) * x * indicator_neg - self.budgets / y, axis=0)
    
    step_size_sgd = gamma/k**c_sgd
    loss_sgd = -np.dot(y_sgd, x)
    indicator_pos_sgd = loss_sgd - xi_sgd >= 0
    indicator_neg_sgd = loss_sgd - xi_sgd < 0
    grad_y_sgd = -2 * alpha * (loss_sgd - xi_sgd) * x * indicator_pos_sgd + -2 * (1 - alpha) * (loss_sgd - xi_sgd) * x * indicator_neg_sgd - budgets/y_sgd
    grad_xi_sgd = -2 * alpha * (loss_sgd - xi_sgd) * indicator_pos_sgd + -2 * (1 - alpha) * (loss_sgd - xi_sgd) * indicator_neg_sgd

    #descent
    y_sgd = y_sgd - step_size_sgd*grad_y_sgd*min(min(y_sgd),1)
    y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
    xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
    # y_bar_sgd_numerator += y_sgd*step_size_sgd
    # y_bar_sgd_denominator += step_size_sgd

    ### SMD
    # gradient
    step_size_smd = gamma/k**c_smd
    loss_smd = -np.dot(y_smd, x)
    indicator_pos_smd = loss_smd - xi_smd >= 0
    indicator_neg_smd = loss_smd - xi_smd < 0
    grad_y_smd = -2 * alpha * (loss_smd - xi_smd) * x * indicator_pos_smd + -2 * (1 - alpha) * (loss_smd - xi_smd) * x * indicator_neg_smd - budgets/y_smd
    grad_xi_smd = -2 * alpha * (loss_smd - xi_smd) * indicator_pos_smd + -2 * (1 - alpha) * (loss_smd - xi_smd) * indicator_neg_smd

    y_smd_min = min(min(y_smd),1)
    y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
    xi_smd = xi_smd - step_size_smd*grad_xi_smd
    sum_y_smd = np.sum(y_smd)
    if sum_y_smd>M:
        y_smd = M/sum_y_smd*y_smd

    if k%freq_y==0:
        y_sgd_s.append(y_sgd)
        xi_sgd_s.append(xi_sgd)
        y_smd_s.append(y_smd)
        xi_smd_s.append(xi_smd)
# Out:
# 100%|██████████| 2/2 [01:01<00:00, 30.53s/it]
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 52
#      50             y_ref += y_smd
#      51             j += 1
# ---> 52 y_ref = y_ref/(j-1)
#      53 SM_theta = y_ref/np.sum(y_ref)
#      56 n_val=1000000
#
# ZeroDivisionError: division by zero

# %%
j
# Out:
# 1

# %%
fig, ax = plt.subplots(2, 2, figsize=(15, 8))
ax[0][0].plot(np.array(y_sgd_s)/np.array(y_sgd_s).sum(axis=1)[:,None], lw=1)
ax[0][0].set_title('SGD')
ax[0][1].plot(np.array(y_smd_s)/np.array(y_smd_s).sum(axis=1)[:,None], lw=1)
ax[0][1].set_title('SMD')
ax[0][0].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
ax[0][1].hlines(SM_theta, 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[0].set_ylim(0, 100) 
# ax[1].set_ylim(0, 20) 

# ax[1][0].plot(xi_sgd_s, lw=1)
# ax[1][0].set_title('SGD')
# ax[1][1].plot(xi_smd_s, lw=1)
# ax[1][1].set_title('SMD')
# ax[1][0].hlines(VaR_port*sum(optim_res), 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[1][1].hlines(VaR_port*sum(optim_res), 0, len(y_sgd_s), colors='black', linestyles='dashed', lw=.5, zorder=0)
# ax[2].set_ylim(0, 100)
# ax[3].set_ylim(0, 20)
plt.tight_layout()
plt.show()

# %%
plt.plot(rb.ys);

# %%
plt.plot(np.array(y_sgd_s)/np.array(y_sgd_s).sum(axis=1)[:,None])
# Out:
# [<matplotlib.lines.Line2D at 0x178d4556610>,
#  <matplotlib.lines.Line2D at 0x178d4556940>,
#  <matplotlib.lines.Line2D at 0x178d4556a00>,
#  <matplotlib.lines.Line2D at 0x178d45565e0>,
#  <matplotlib.lines.Line2D at 0x178d400bc10>,
#  <matplotlib.lines.Line2D at 0x178d400b250>,
#  <matplotlib.lines.Line2D at 0x178d400b730>,
#  <matplotlib.lines.Line2D at 0x178d400b3d0>,
#  <matplotlib.lines.Line2D at 0x178d400b220>,
#  <matplotlib.lines.Line2D at 0x178d400b4f0>,
#  <matplotlib.lines.Line2D at 0x178d4556640>,
#  <matplotlib.lines.Line2D at 0x178d400b670>,
#  <matplotlib.lines.Line2D at 0x178d400b940>,
#  <matplotlib.lines.Line2D at 0x178d400b790>,
#  <matplotlib.lines.Line2D at 0x178d3d348e0>,
#  <matplotlib.lines.Line2D at 0x178d1f59070>,
#  <matplotlib.lines.Line2D at 0x178d400b610>,
#  <matplotlib.lines.Line2D at 0x178d400bb80>,
#  <matplotlib.lines.Line2D at 0x178d400b310>,
#  <matplotlib.lines.Line2D at 0x178d400b1c0>,
#  <matplotlib.lines.Line2D at 0x178d400b6d0>,
#  <matplotlib.lines.Line2D at 0x178d3a227f0>,
#  <matplotlib.lines.Line2D at 0x178d3a22f70>,
#  <matplotlib.lines.Line2D at 0x178d3a22a00>,
#  <matplotlib.lines.Line2D at 0x178d3a22a90>]

# %%
y_smd_s[-1]/y_smd_s[-1].sum()
# Out:
# array([0.03436151, 0.03650372, 0.05524621, 0.05101207, 0.0372502 ,
#        0.05764525, 0.03605166, 0.02974357, 0.03590321, 0.04852165,
#        0.03285054, 0.02918295, 0.02943271, 0.03147521, 0.03681342,
#        0.05045243, 0.03535343, 0.03017348, 0.0491022 , 0.03433083,
#        0.04709076, 0.03907779, 0.03036565, 0.05107617, 0.05098337])

# %%
# %%time
rb = RiskBudgeting(risk_measure='variantile',
                   alpha=0.9,
                   budgets='ERC')

rb.solve(SM_model.rvs(2000000), epochs=5)
rb.x
# Out:
# CPU times: total: 39.7 s
# Wall time: 36 s
# array([0.0354673 , 0.03834425, 0.049359  , 0.04802822, 0.03775399,
#        0.05445657, 0.03710837, 0.02920425, 0.03548968, 0.04990095,
#        0.03361524, 0.02924606, 0.03381557, 0.03190834, 0.04023153,
#        0.04946632, 0.03866623, 0.0284463 , 0.04897549, 0.03470373,
#        0.04751382, 0.04137148, 0.02979265, 0.0511925 , 0.04594218])

# %%
rb.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 rb.epochs
#
# AttributeError: 'RiskBudgeting' object has no attribute 'epochs'

# %%
y_smd_s[-1]/y_smd_s[-1].sum()
# Out:
# array([0.15260811, 0.09989393, 0.11210913, 0.14820106, 0.07669528,
#        0.07747898, 0.0713693 , 0.10674103, 0.07533996, 0.07956321])

# %%
SM_theta
# Out:
# array([0.15641687, 0.07871302, 0.08130677, 0.09026644, 0.09835644,
#        0.11525188, 0.08779208, 0.07820055, 0.10983053, 0.10386543])

# %%
SM_theta*(vcv@SM_theta)
# Out:
# array([2.45349975e-05, 2.45355306e-05, 2.45358966e-05, 2.45358587e-05,
#        2.45348331e-05, 2.45358675e-05, 2.45347622e-05, 2.45357940e-05,
#        2.45348978e-05, 2.45375572e-05])

# %%
budgets
# Out:
# array([0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01,
#        0.01])

# %%
StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_sgd, alpha) - np.dot(budgets, np.log(y_sgd)) - optimal_loss
# Out:
# 1.0478230163290612

# %%
StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_smd, alpha) - np.dot(budgets, np.log(y_smd)) - optimal_loss
# Out:
# 0.00017491870544095178

# %%
np.mean(abs(SM_theta-y_sgd/y_sgd.sum()))
# Out:
# 0.000152000569585123

# %%
np.mean(abs(SM_theta-y_smd/y_smd.sum()))
# Out:
# 9.213695317880166e-05

# %%
for d in [10,25,50,100,250]:

    errors_sgd = []
    errors_smd = []

    norms_sgd = []
    norms_smd = []

    for i in range(100):
        selected_indices = np.random.choice(range(len(first_level_index)), d, replace = False)
        assets = first_level_index[selected_indices]
        nb_asset = len(assets)
        df = df_all[assets]
        X = df.values

        ### Fit Student-t mixture (2 components) to chosen stock returns
        n_sm = 2
        SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [2.5,4]).fit(X)

        # ERC
        budgets = np.ones(nb_asset)/nb_asset 
        # Expected Shortfall alpha
        alpha = .95 

        SM_theta, optim_res = StudentMixtureExpectedShortfall(SM_model).solve_risk_budgeting(budgets, alpha, on_simplex=False, kappa=1, method=None, maxiter=15000)
        VaR_port = StudentMixtureExpectedShortfall(SM_model).value_at_risk(SM_theta, alpha)
        ES_port = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(SM_theta, alpha)
        risk_contribs = SM_theta * StudentMixtureExpectedShortfall(SM_model).expected_shortfall_gradient(SM_theta, alpha)

        optimal_loss = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(optim_res.x, alpha) - np.dot(budgets, np.log(optim_res.x))

        n_val=1000000
        X = SM_model.rvs(n_val)
        np.random.shuffle(X)

        gamma = 10

        y_sgd = budgets / np.std(X, axis=0)
        xi_sgd = 0
        c_sgd = .65

        y_smd = budgets / np.std(X, axis=0)
        xi_smd = 0
        c_smd = .8
        M = 500

        y_sgd_s = [y_sgd]
        xi_sgd_s = [xi_sgd]
        y_bar_sgd_s = [y_sgd]
        y_bar_sgd_numerator = 0
        y_bar_sgd_denominator = 0

        y_smd_s = [y_smd]
        xi_smd_s = [xi_smd]
        y_bar_smd_s = [y_smd]
        y_bar_smd_numerator = 0
        y_bar_smd_denominator = 0

        error_sgd = []
        error_smd = []

        norm_sgd = []
        norm_smd = []

        freq_error = 100000

        for k in range(1, n_val):
            x = X[k]
            
            ### SGD
            # gradient
            step_size_sgd = gamma/k**c_sgd
            indicator_sgd = -np.dot(y_sgd, x) - xi_sgd >= 0
            grad_y_sgd = -x/(1-alpha)*indicator_sgd - budgets/y_sgd
            grad_xi_sgd = 1 - (1 / (1 - alpha)) * indicator_sgd

            #descent
            y_sgd = y_sgd - step_size_sgd*grad_y_sgd
            y_sgd = np.where(y_sgd <= 0, 1e-04, y_sgd)
            xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
            y_bar_sgd_numerator += y_sgd*step_size_sgd
            y_bar_sgd_denominator += step_size_sgd

            ### SMD
            # gradient
            step_size_smd = gamma/k**c_smd
            indicator_smd = -np.dot(y_smd, x) - xi_smd >= 0
            grad_y_smd = -x/(1-alpha)*indicator_smd - budgets/y_smd
            grad_xi_smd = 1 - (1 / (1 - alpha)) * indicator_smd

            y_smd_min = min(min(y_smd),1)
            y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
            xi_smd = xi_smd - step_size_smd*grad_xi_smd
            sum_y_smd = np.sum(y_smd)
            if sum_y_smd>M:
                y_smd = M/sum_y_smd*y_smd
            y_bar_smd_numerator += y_smd*step_size_smd
            y_bar_smd_denominator += step_size_smd

            # y_sgd_s.append(y_sgd)
            # xi_sgd_s.append(xi_sgd)
            # y_bar_sgd_s.append(y_bar_sgd_numerator/y_bar_sgd_denominator)

            # y_smd_s.append(y_smd)
            # xi_smd_s.append(xi_smd)
            # y_bar_smd_s.append(y_bar_smd_numerator/y_bar_smd_denominator)

            if k%freq_error==0:
                error_sgd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_sgd, alpha) - np.dot(budgets, np.log(y_sgd)) - optimal_loss)
                error_smd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_smd, alpha) - np.dot(budgets, np.log(y_smd)) - optimal_loss)

                norm_sgd.append(np.mean(SM_theta-y_sgd/y_sgd.sum()))
                norm_smd.append(np.mean(SM_theta-y_smd/y_smd.sum()))

        errors_sgd.append(error_sgd)
        errors_smd.append(error_smd)

        norms_sgd.append(norm_sgd)
        norms_smd.append(norm_smd)
        np.save(str(d)+'_sgd_errors.npy', np.array(errors_sgd))
        np.save(str(d)+'_smd_errors.npy', np.array(errors_smd))

# %%
### Import stock price data for model calibration
freq = 'B'
assets = ['JPM UN Equity', 'PFE UN Equity', 'XOM UN Equity']
nb_asset = len(assets)

df_all = pd.concat([pd.read_excel('Data/SP_RC.xlsx',index_col=0, header=[0,1]), pd.read_excel('Data/SP_RC2.xlsx',index_col=0, header=[0,1])])
df_all = df_all.dropna(how='all').dropna(axis=1)
df_all = df_all.pct_change().dropna()
df_all = df_all.replace([np.inf, -np.inf], np.nan)
df_all = df_all[~df_all.index.duplicated(keep='first')]
df = df_all[assets]

X = df.values
print(X.shape)
# Out:
# (3446, 3)

# %%
selected_indices = np.random.choice(range(len(first_level_index)), 50, replace = False)
assets = first_level_index[selected_indices]
nb_asset = len(assets)
df = df_all[assets]
X = df.values

# %%
### Fit Student-t mixture (2 components) to chosen stock returns
n_sm = 2
SM_model = sm.StudentMixture(n_components=n_sm, fixed_dofs = True, dofs_init = [2.5,4]).fit(X)

# %%
### Print model parameters 
print("==== Number of assets ====")
print(nb_asset)
print("==== Number of mixture components ====")
print(n_sm)
print("==== Weights (probability) parameters ====")
print(SM_model.weights_)
print("==== Degree of freedom parameters ====")
print(SM_model.dofs_)
print("==== Location parameters ====")
print(SM_model.locations_)
print("==== Scale parameters ====")
print(SM_model.scales_)
# Out:
# ==== Number of assets ====
# 3
# ==== Number of mixture components ====
# 2
# ==== Weights (probability) parameters ====
# [0.57536895 0.42463105]
# ==== Degree of freedom parameters ====
# [2.5 4. ]
# ==== Location parameters ====
# [[-0.00070383 -0.00097538 -0.00182552]
#  [ 0.00160405  0.00209373  0.00204925]]
# ==== Scale parameters ====
# [[[2.45546634e-04 7.09484995e-05 8.74424168e-05]
#   [7.09484995e-05 6.90364583e-05 4.56142046e-05]
#   [8.74424168e-05 4.56142046e-05 1.04945729e-04]]
#
#  [[9.06453859e-05 1.79115311e-05 4.41578466e-05]
#   [1.79115311e-05 1.24689694e-04 1.80013614e-05]
#   [4.41578466e-05 1.80013614e-05 1.06182789e-04]]]

# %%
### Compute the Risk Budgeting portfolio under the above model

# ERC
budgets = np.ones(nb_asset)/nb_asset 
# Expected Shortfall alpha
alpha = .95 

SM_theta, optim_res = StudentMixtureExpectedShortfall(SM_model).solve_risk_budgeting(budgets, alpha, on_simplex=False, kappa=1, method=None, maxiter=15000)
VaR_port = StudentMixtureExpectedShortfall(SM_model).value_at_risk(SM_theta, alpha)
ES_port = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(SM_theta, alpha)
risk_contribs = SM_theta * StudentMixtureExpectedShortfall(SM_model).expected_shortfall_gradient(SM_theta, alpha)

print('==== Target Risk Bugdets ====')
print(np.round(budgets, 4))
print('==== $y^*$ ====')
print(np.round(optim_res.x, 4))

print('==== Risk Budgeting portfolio ($u^*$) ====')
print(np.round(SM_theta, 4))
print('==== VaR of the portfolio ====')
print(np.round(VaR_port, 4))
print('==== Expected Shortfall of the portfolio ====')
print(np.round(ES_port, 4))
print('==== Risk Contributions ====')
print(np.round(risk_contribs, 5))
print('==== Risk Contributions (normalized) ====')
print(np.round(risk_contribs/sum(risk_contribs), 2))
# Out:
# ==== Target Risk Bugdets ====
# [0.3333 0.3333 0.3333]
# ==== $y^*$ ====
# [ 6.9959 11.6543  9.8087]
# ==== Risk Budgeting portfolio ($u^*$) ====
# [0.2458 0.4095 0.3447]
# ==== VaR of the portfolio ====
# 0.0202
# ==== Expected Shortfall of the portfolio ====
# 0.0351
# ==== Risk Contributions ====
# [0.01171 0.01171 0.01171]
# ==== Risk Contributions (normalized) ====
# [0.33 0.33 0.33]

# %%
StudentMixtureExpectedShortfall(SM_model).solve_risk_budgeting(budgets, alpha, on_simplex=False, kappa=1, method=None, maxiter=15000)
# Out:
# (array([0.24582584, 0.40951357, 0.34466059]),
#    message: CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#    success: True
#     status: 0
#        fun: -1.2280854838694133
#          x: [ 6.996e+00  1.165e+01  9.809e+00]
#        nit: 13
#        jac: [ 1.110e-07  2.220e-07  1.332e-07]
#       nfev: 56
#       njev: 14
#   hess_inv: <3x3 LbfgsInvHessProduct with dtype=float64>)

# %%
optimal_loss = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(optim_res.x, alpha) - np.dot(budgets, np.log(optim_res.x))
optimal_loss
# Out:
# -1.2280854838694133

# %% [markdown]
# ### SMD vs. SGD - Error analysis

# %%
np.random.seed(0)

errors_sgd = []
errors_smd = []

for i in tqdm(range(100)):

    n_val=1000000
    X = SM_model.rvs(n_val)
    np.random.shuffle(X)

    alpha = .95
    gamma = 10

    y_sgd = budgets / np.std(X, axis=0)
    xi_sgd = 0
    c_sgd = .65

    y_smd = budgets / np.std(X, axis=0)
    xi_smd = 0
    c_smd = .8
    M = 500

    y_sgd_s = [y_sgd]
    xi_sgd_s = [xi_sgd]
    y_bar_sgd_s = [y_sgd]
    y_bar_sgd_numerator = 0
    y_bar_sgd_denominator = 0

    y_smd_s = [y_smd]
    xi_smd_s = [xi_smd]
    y_bar_smd_s = [y_smd]
    y_bar_smd_numerator = 0
    y_bar_smd_denominator = 0

    error_sgd = []
    error_smd = []

    freq_error = 50

    for k in range(1, n_val):
        x = X[k]
        
        ### SGD
        # gradient
        step_size_sgd = gamma/k**c_sgd
        indicator_sgd = -np.dot(y_sgd, x) - xi_sgd >= 0
        grad_y_sgd = -x/(1-alpha)*indicator_sgd - budgets/y_sgd
        grad_xi_sgd = 1 - (1 / (1 - alpha)) * indicator_sgd

        #descent
        y_sgd = y_sgd - step_size_sgd*grad_y_sgd
        y_sgd = np.where(y <= 0, 1e-04, y_sgd)
        xi_sgd = xi_sgd - step_size_sgd*grad_xi_sgd
        y_bar_sgd_numerator += y_sgd*step_size_sgd
        y_bar_sgd_denominator += step_size_sgd

        ### SMD
        # gradient
        step_size_smd = gamma/k**c_smd
        indicator_smd = -np.dot(y_smd, x) - xi_smd >= 0
        grad_y_smd = -x/(1-alpha)*indicator_smd - budgets/y_smd
        grad_xi_smd = 1 - (1 / (1 - alpha)) * indicator_smd

        y_smd_min = min(min(y_smd),1)
        y_smd = y_smd*np.exp(-step_size_smd*y_smd_min*grad_y_smd)
        xi_smd = xi_smd - step_size_smd*grad_xi_smd
        sum_y_smd = np.sum(y_smd)
        if sum_y_smd>M:
            y_smd = M/sum_y_smd*y_smd
        y_bar_smd_numerator += y_smd*step_size_smd
        y_bar_smd_denominator += step_size_smd

        # y_sgd_s.append(y_sgd)
        # xi_sgd_s.append(xi_sgd)
        # y_bar_sgd_s.append(y_bar_sgd_numerator/y_bar_sgd_denominator)

        # y_smd_s.append(y_smd)
        # xi_smd_s.append(xi_smd)
        # y_bar_smd_s.append(y_bar_smd_numerator/y_bar_smd_denominator)

        if k%freq_error==0:
            error_sgd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_sgd, alpha) - np.dot(budgets, np.log(y_sgd)) - optimal_loss)
            error_smd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_smd, alpha) - np.dot(budgets, np.log(y_smd)) - optimal_loss)
    
    errors_sgd.append(error_sgd)
    errors_smd.append(error_smd)

    np.save('sgd_errors.npy', np.array(errors_sgd))
    np.save('smd_errors.npy', np.array(errors_smd))
# Out:
#  29%|██▉       | 29/100 [1:36:57<5:11:47, 263.49s/it]C:\Users\arcetingoz\AppData\Local\Temp\ipykernel_1112\1483225849.py:82: RuntimeWarning: invalid value encountered in log
#   error_sgd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_sgd, alpha) - np.dot(budgets, np.log(y_sgd)) - optimal_loss)
#  97%|█████████▋| 97/100 [5:29:53<10:12, 204.05s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 82
#      73     # y_sgd_s.append(y_sgd)
#      74     # xi_sgd_s.append(xi_sgd)
#      75     # y_bar_sgd_s.append(y_bar_sgd_numerator/y_bar_sgd_denominator)
#    (...)
#      78     # xi_smd_s.append(xi_smd)
#      79     # y_bar_smd_s.append(y_bar_smd_numerator/y_bar_smd_denominator)
#      81     if k%50==0:
# ---> 82         error_sgd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_sgd, alpha) - np.dot(budgets, np.log(y_sgd)) - optimal_loss)
#      83         error_smd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_smd, alpha) - np.dot(budgets, np.log(y_smd)) - optimal_loss)
#      85 errors_sgd.append(error_sgd)
#
# File c:\Users\arcetingoz\Desktop\Mirror_Descent_for_RB\Lib\module\movidas.py:808, in StudentMixtureExpectedShortfall.expected_shortfall(self, theta, alpha)
#     807 def expected_shortfall(self, theta, alpha):
# --> 808     var = self.value_at_risk(theta, alpha)
#     809     probs = self.model.weights_
#     810     means = np.dot(self.model.locations_, theta)
#
# File c:\Users\arcetingoz\Desktop\Mirror_Descent_for_RB\Lib\module\movidas.py:787, in StudentMixtureExpectedShortfall.value_at_risk(self, theta, alpha, method, a, b, tol, max_iter)
#     785 for _ in range(10):
#     786     eq = np.dot(probs, t.cdf((var + means) / scales, df=dofs))
# --> 787     diff = np.dot(probs / scales, t.pdf((var + means) / scales, df=dofs))
#     788     var = var - (eq - alpha) / diff
#     789 return var
#
# File c:\Users\arcetingoz\AppData\Local\anaconda3\envs\mirror_descent\lib\site-packages\scipy\stats\_distn_infrastructure.py:2098, in rv_continuous.pdf(self, x, *args, **kwds)
#    2096 cond = cond0 & cond1
#    2097 output = zeros(shape(cond), dtyp)
# -> 2098 putmask(output, (1-cond0)+np.isnan(x), self.badvalue)
#    2099 if np.any(cond):
#    2100     goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#
# File <__array_function__ internals>:180, in putmask(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
errors_sgd = []
errors_smd = []
for i in tqdm(ns):
    errors_sgd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_sgd_s[i], alpha) - np.dot(budgets, np.log(y_sgd_s[i])) - optimal_loss)
    errors_smd.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_smd_s[i], alpha) - np.dot(budgets, np.log(y_smd_s[i])) - optimal_loss)
# Out:
# 100%|██████████| 20000/20000 [01:53<00:00, 175.67it/s]

# %%
errors_sgd_bar = []
errors_smd_bar = []
for i in tqdm(ns):
    errors_sgd_bar.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_bar_sgd_s[i], alpha) - np.dot(budgets, np.log(y_bar_sgd_s[i])) - optimal_loss)
    errors_smd_bar.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_bar_smd_s[i], alpha) - np.dot(budgets, np.log(y_bar_smd_s[i])) - optimal_loss)
# Out:
# 100%|██████████| 20000/20000 [01:57<00:00, 169.55it/s]

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
ax[0].plot(ns, errors_sgd);
ax[0].plot(ns, errors_smd);
ax[0].set_yscale('log')

ax[1].plot(ns, errors_sgd_bar);
ax[1].plot(ns, errors_smd_bar);
ax[1].set_yscale('log')

# %%
y_sgd_s[-1]/sum(y_sgd_s[-1])
# Out:
# array([0.24316013, 0.40984939, 0.34699048])

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
ax[0].plot(y_sgd_s);
ax[1].plot(y_smd_s);

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
ax[0].plot(y_sgd_s);
ax[1].plot(y_smd_s);

# %%
fig, ax = plt.subplots(1,2, figsize=(15,4))
ax[0].plot(y_sgd_s);
ax[1].plot(y_smd_s);

# %%
y_sgd_s[-1]
# Out:
# array([ 7.00890287, 11.81359223, 10.00173283])

# %%
y_smd_s[-1]
# Out:
# array([ 6.75119649, 11.65253988,  9.8515459 ])

# %%
# %%time
# we define our risk budgeting problem for expected shortfall
rb = RiskBudgeting(risk_measure='expected_shortfall',
                   alpha=0.95,
                   budgets='ERC')
rb.solve(X, 
         epochs=1,
         minibatch_size=1,
         eta_0_y=10, 
         eta_0_t=10,
         c=0.65,
         polyak_ruppert=0.2,
         store=True)

print('==== True Risk Budgeting portfolio ====')
print(np.round(SM_theta, 4))
print('==== Risk Budgeting portfolio from SGD ====')
print(np.round(rb.x, 4))

plt.plot(rb.ys);
# Out:
# ==== True Risk Budgeting portfolio ====
# [0.2458 0.4095 0.3447]
# ==== Risk Budgeting portfolio from SGD ====
# [0.2442 0.4098 0.346 ]
# CPU times: total: 34.5 s
# Wall time: 35.1 s

# %%
# %%time
M=30
rb_md = stoch_sol(X, M, n_val, nb_asset, budgets, n_epochs=1, gamma=10)
# Out:
# 100%|██████████| 1/1 [00:43<00:00, 43.86s/it]
# CPU times: total: 43 s
# Wall time: 43.9 s

# %% [markdown]
# #### Error analysis

# %%
y_s = np.array(rb.ys)
x,y,z = np.array(rb_md.y_bars).shape
y_s_md = np.array(rb_md.y_bars).reshape(x,z)
optimal_loss = StudentMixtureExpectedShortfall(SM_model).expected_shortfall(optim_res.x, alpha) - np.dot(budgets, np.log(optim_res.x))
optimal_loss
# Out:
# -1.2280854838694133

# %%
errors = []
errors_md = []
for i in tqdm(range(0,len(y_s)-1,100)):
    errors.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_s[i], alpha) - np.dot(budgets, np.log(y_s[i])) - optimal_loss)
    errors_md.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_s_md[i], alpha) - np.dot(budgets, np.log(y_s_md[i])) - optimal_loss)
# Out:
# 100%|██████████| 10000/10000 [00:43<00:00, 232.36it/s]

# %%
len(y_s)
# Out:
# 1000001

# %%
len(y_s_md)
# Out:
# 1000000

# %%
plt.plot(range(0,len(y_s)-1,100), errors)
plt.plot(range(0,len(y_s)-1,100), errors_md)
plt.yscale('log')

# %%
min(errors)
# Out:
# 1.9125464545410864e-08

# %%
y_s
# Out:
# array([[12.28042621, 19.61747494, 17.56669541],
#        [13.63759952, 20.46705761, 18.51546047],
#        [14.41642709, 20.9860056 , 19.08910748],
#        ...,
#        [ 7.05348165, 11.64680376,  9.9984121 ],
#        [ 7.05377912, 11.64698391,  9.99862196],
#        [ 7.05407658, 11.64716406,  9.99883181]])

# %%
# %%time
M=50
solution_md = stoch_sol(X, M, n_val, nb_asset, budgets, n_epochs=1)
# Out:
# 100%|██████████| 1/1 [00:26<00:00, 26.40s/it]
# CPU times: total: 25.8 s
# Wall time: 26.4 s

# %%
y_s_md = solution_md.ys.T

# %%
errors_md = []
for i in tqdm(range(0,len(y_s_md),50)):
    errors_md.append(StudentMixtureExpectedShortfall(SM_model).expected_shortfall(y_s_md[i], alpha) - np.dot(budgets, np.log(y_s_md[i])) - optimal_loss)
# Out:
# 100%|██████████| 20000/20000 [00:41<00:00, 482.90it/s]

# %%
plt.plot(range(0,len(y_s_md),50), errors_md)
plt.yscale('log')
